# %% [markdown]
# 60-feature dataset

# %%
import pandas as pd
import sys
sys.path.append("..")
from tools.feature_selection import feat_select
from tools.feature_selection import rfe_select
from tools import data_parser as dp

# %%
bert_data = "../data/combined_bert_df.csv"
df = pd.read_csv(bert_data)

light, heavy, temp = dp.data_extract('../data/combined_datasets.csv')

X = df
Y = temp

# %%
# %%time
reduced_data = feat_select(X,Y,60)
# Out:
# CPU times: total: 0 ns
# Wall time: 21 ms

# %%
reduced_data.shape
# Out:
# (177, 60)

# %%
# %%time
rfe_reduced = rfe_select(X,Y,60)
# Out:
# CPU times: total: 5min 30s
# Wall time: 8min 34s

# %%
rfe_reduced.shape
# Out:
# (60,)

# %%
X_new = X.loc[:,rfe_reduced]

# %%
X_new.shape
# Out:
# (177, 60)

# %%
X_new.to_csv("../data/combined_datasets_60.csv", index=False)

# %%
import sys

import seaborn as sns

sys.path.append("..")
from tools import data_parser as dp
import joblib
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
from statistics import mean
from randomforest import random_forest_CV as rf
from data_visualisation import rf_vis

# %%
bert_data_512 = "../data/combined_bert_df.csv"
bert_data_60 = "../data/combined_datasets_60.csv"
df = pd.read_csv(bert_data_60)

light, heavy, temp = dp.data_extract('../data/combined_datasets.csv')

X = df
y = temp

# %%
# %%time
model = rf.rf_cv(X, y)
# Out:
# Fitting 10 folds for each of 20 candidates, totalling 200 fits
# Fitting 10 folds for each of 20 candidates, totalling 200 fits
# Fitting 10 folds for each of 20 candidates, totalling 200 fits
# Fitting 10 folds for each of 20 candidates, totalling 200 fits
# Fitting 10 folds for each of 20 candidates, totalling 200 fits
# Fitting 10 folds for each of 20 candidates, totalling 200 fits
# Fitting 10 folds for each of 20 candidates, totalling 200 fits
# Fitting 10 folds for each of 20 candidates, totalling 200 fits
# Fitting 10 folds for each of 20 candidates, totalling 200 fits
# Fitting 10 folds for each of 20 candidates, totalling 200 fits
# Validation MAE: 4.125 (0.657)
# Validation R2: 0.070 (0.313)
# Validation Pearsonr: 0.437 (0.281)
# Test MAE: 3.374
# Test R2: 0.401
# Test Pearsonr: 0.714
# CPU times: total: 5.88 s
# Wall time: 1min 35s

# %%
import sys
sys.path.append("..")
from SVM import svm_cv
import pandas as pd
from tools import data_parser as dp

# %%
svm_model = svm_cv(X,y)
# Out:
# Validation MAE: 4.309 (0.967)
# Validation R2: -0.023 (0.198)
# Validation Pearsonr: 0.232 (0.232)
# Test MAE: 3.967
# Test R2: 0.222
# Test Pearsonr: 0.695

# %%
import joblib

# %%
joblib.dump(svm_model, "../models/05062023_svm_60.joblib")
joblib.dump(model, "../models/05062023_rf_60.joblib")
# Out:
# ['../models/05062023_rf_60.joblib']

# %%
from scipy.stats import stats
from sklearn import ensemble
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from matplotlib import pyplot as plt


def gradient_boosting_regression(X, y):
    """Gradient Boosting for regression

    Parameters
    ----------
    X : array-like of shape = [n_samples, n_features]
        The training input samples.
    y : array-like, shape = [n_samples]
        The target values (real numbers in regression).

    Returns
    -------
    reg : regression model.
    """
    params = {
        "n_estimators": 5000,
        "max_depth": 4,
        "min_samples_split": 5,
        "learning_rate": 0.01,
        "loss": "squared_error",
    }
    sns.set_style(style='white')

    X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=0.1, random_state=13
    )

    reg = ensemble.GradientBoostingRegressor(**params)
    reg.fit(X_train, y_train)

    mse = mean_squared_error(y_test, reg.predict(X_test))
    mae = mean_absolute_error(y_test, reg.predict(X_test))
    pearsonr = stats.pearsonr(y_test, reg.predict(X_test))
    r2 = r2_score(y_test, reg.predict(X_test))

    print("The mean squared error (MSE) on test set: {:.4f}".format(mse))
    print("The mean absolute error (MAE) on test set: {:.4f}".format(mae))
    print("The pearson coeffieicent on test set: {:.4f}".format(pearsonr[0]))
    print("The r2 on test set: {:.4f}".format(r2))

    test_score = np.zeros((params["n_estimators"],), dtype=np.float64)
    for i, y_pred in enumerate(reg.staged_predict(X_test)):
        test_score[i] = mean_absolute_error(y_test, y_pred)

    fig = plt.figure(figsize=(6, 6))
    plt.subplot(1, 1, 1)
    plt.title("Deviance")
    plt.plot(
        np.arange(params["n_estimators"]) + 1,
        reg.train_score_,
        "b-",
        label="Training Set Deviance"
    )
    plt.legend(loc="upper right")
    plt.xlabel("Boosting Iterations")
    plt.ylabel("Deviance")
    fig.tight_layout()
    plt.show()

    # plot actual vs predicted
    fig = plt.figure(figsize=(6, 6))
    plt.subplot(1, 1, 1)
    plt.scatter(reg.predict(X_test),y_test, alpha=0.5)
    plt.plot([60,80], [60,80], 'r--', lw=2)
    plt.ylabel("Actual")
    plt.xlabel("Predicted")
    plt.title(f'Predictions vs. Actual\nMAE={mae:.2f}, R2={r2:.2f}, Pearsonr={pearsonr[0]:.2f}')
    fig.tight_layout()
    plt.show()

    return reg

# %%
gb_model = gradient_boosting_regression(X,y)
# Out:
# C:\Users\toon_\AppData\Local\Temp\ipykernel_34064\551005237.py:39: DeprecationWarning: Please use `pearsonr` from the `scipy.stats` namespace, the `scipy.stats.stats` namespace is deprecated.
#   pearsonr = stats.pearsonr(y_test, reg.predict(X_test))
# The mean squared error (MSE) on test set: 10.1592
# The mean absolute error (MAE) on test set: 2.6080
# The pearson coeffieicent on test set: 0.8415
# The r2 on test set: 0.6356

# %%
from scipy.stats import probplot

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.1, random_state=13
)

# %%
y_pred = model.predict(X_test)
residuals = y_test - y_pred

# create QQ plot
fig, ax = plt.subplots(figsize=(8, 5))
probplot(residuals, plot=ax)
ax.set_title('QQ Plot of Residuals')
ax.set_xlabel('Theoretical Quantiles')
ax.set_ylabel('Sample Quantiles')
plt.show()

# %%
joblib.dump(gb_model, "../models/05062023_gb_60.joblib")
# Out:
# ['../models/05062023_gb_60.joblib']

# %%
from RNN import rnn_cv

# %%
rnn_cv(X,y)
# Out:
# Epoch 1/100
# 13/13 - 3s - loss: 70.3731 - val_loss: 67.7849 - 3s/epoch - 231ms/step
# Epoch 2/100
# 13/13 - 0s - loss: 68.2464 - val_loss: 65.5125 - 157ms/epoch - 12ms/step
# Epoch 3/100
# 13/13 - 0s - loss: 65.5692 - val_loss: 62.5202 - 145ms/epoch - 11ms/step
# Epoch 4/100
# 13/13 - 0s - loss: 61.8480 - val_loss: 58.3254 - 146ms/epoch - 11ms/step
# Epoch 5/100
# 13/13 - 0s - loss: 57.5956 - val_loss: 54.5455 - 157ms/epoch - 12ms/step
# Epoch 6/100
# 13/13 - 0s - loss: 54.3198 - val_loss: 51.5925 - 157ms/epoch - 12ms/step
# Epoch 7/100
# 13/13 - 0s - loss: 51.7700 - val_loss: 49.2848 - 160ms/epoch - 12ms/step
# Epoch 8/100
# 13/13 - 0s - loss: 49.7508 - val_loss: 47.3425 - 160ms/epoch - 12ms/step
# Epoch 9/100
# 13/13 - 0s - loss: 47.8793 - val_loss: 45.5007 - 170ms/epoch - 13ms/step
# Epoch 10/100
# 13/13 - 0s - loss: 46.0818 - val_loss: 43.7235 - 146ms/epoch - 11ms/step
# Epoch 11/100
# 13/13 - 0s - loss: 44.3729 - val_loss: 42.0480 - 134ms/epoch - 10ms/step
# Epoch 12/100
# 13/13 - 0s - loss: 42.7209 - val_loss: 40.4123 - 157ms/epoch - 12ms/step
# Epoch 13/100
# 13/13 - 0s - loss: 41.1067 - val_loss: 38.8181 - 141ms/epoch - 11ms/step
# Epoch 14/100
# 13/13 - 0s - loss: 39.5387 - val_loss: 37.2653 - 137ms/epoch - 11ms/step
# Epoch 15/100
# 13/13 - 0s - loss: 38.0009 - val_loss: 35.7396 - 168ms/epoch - 13ms/step
# Epoch 16/100
# 13/13 - 0s - loss: 36.4865 - val_loss: 34.2352 - 176ms/epoch - 14ms/step
# Epoch 17/100
# 13/13 - 0s - loss: 34.9913 - val_loss: 32.7478 - 165ms/epoch - 13ms/step
# Epoch 18/100
# 13/13 - 0s - loss: 33.5117 - val_loss: 31.2750 - 155ms/epoch - 12ms/step
# Epoch 19/100
# 13/13 - 0s - loss: 32.0454 - val_loss: 29.8146 - 168ms/epoch - 13ms/step
# Epoch 20/100
# 13/13 - 0s - loss: 30.5905 - val_loss: 28.3648 - 156ms/epoch - 12ms/step
# Epoch 21/100
# 13/13 - 0s - loss: 29.1455 - val_loss: 26.9243 - 160ms/epoch - 12ms/step
# Epoch 22/100
# 13/13 - 0s - loss: 27.7092 - val_loss: 25.4917 - 186ms/epoch - 14ms/step
# Epoch 23/100
# 13/13 - 0s - loss: 26.2804 - val_loss: 24.0665 - 153ms/epoch - 12ms/step
# Epoch 24/100
# 13/13 - 0s - loss: 24.8586 - val_loss: 22.6478 - 152ms/epoch - 12ms/step
# Epoch 25/100
# 13/13 - 0s - loss: 23.4428 - val_loss: 21.2349 - 169ms/epoch - 13ms/step
# Epoch 26/100
# 13/13 - 0s - loss: 22.0327 - val_loss: 19.8273 - 170ms/epoch - 13ms/step
# Epoch 27/100
# 13/13 - 0s - loss: 20.6275 - val_loss: 18.4246 - 168ms/epoch - 13ms/step
# Epoch 28/100
# 13/13 - 0s - loss: 19.2270 - val_loss: 17.0261 - 186ms/epoch - 14ms/step
# Epoch 29/100
# 13/13 - 0s - loss: 17.8306 - val_loss: 15.6317 - 154ms/epoch - 12ms/step
# Epoch 30/100
# 13/13 - 0s - loss: 16.4573 - val_loss: 14.2481 - 158ms/epoch - 12ms/step
# Epoch 31/100
# 13/13 - 0s - loss: 15.1352 - val_loss: 12.8893 - 173ms/epoch - 13ms/step
# Epoch 32/100
# 13/13 - 0s - loss: 13.8213 - val_loss: 11.5458 - 148ms/epoch - 11ms/step
# Epoch 33/100
# 13/13 - 0s - loss: 12.5379 - val_loss: 10.2189 - 141ms/epoch - 11ms/step
# Epoch 34/100
# 13/13 - 0s - loss: 11.3041 - val_loss: 9.0117 - 145ms/epoch - 11ms/step
# Epoch 35/100
# 13/13 - 0s - loss: 10.1299 - val_loss: 7.8336 - 151ms/epoch - 12ms/step
# Epoch 36/100
# 13/13 - 0s - loss: 9.0304 - val_loss: 6.7902 - 141ms/epoch - 11ms/step
# Epoch 37/100
# 13/13 - 0s - loss: 8.0073 - val_loss: 5.9673 - 125ms/epoch - 10ms/step
# Epoch 38/100
# 13/13 - 0s - loss: 7.2021 - val_loss: 5.3090 - 127ms/epoch - 10ms/step
# Epoch 39/100
# 13/13 - 0s - loss: 6.5634 - val_loss: 4.8011 - 129ms/epoch - 10ms/step
# Epoch 40/100
# 13/13 - 0s - loss: 6.0753 - val_loss: 4.4301 - 145ms/epoch - 11ms/step
# Epoch 41/100
# 13/13 - 0s - loss: 5.6963 - val_loss: 4.1695 - 137ms/epoch - 11ms/step
# Epoch 42/100
# 13/13 - 0s - loss: 5.4266 - val_loss: 3.9841 - 141ms/epoch - 11ms/step
# Epoch 43/100
# 13/13 - 0s - loss: 5.2358 - val_loss: 3.8734 - 146ms/epoch - 11ms/step
# Epoch 44/100
# 13/13 - 0s - loss: 5.0801 - val_loss: 3.8232 - 131ms/epoch - 10ms/step
# Epoch 45/100
# 13/13 - 0s - loss: 4.9933 - val_loss: 3.8006 - 125ms/epoch - 10ms/step
# Epoch 46/100
# 13/13 - 0s - loss: 4.9416 - val_loss: 3.7802 - 126ms/epoch - 10ms/step
# Epoch 47/100
# 13/13 - 0s - loss: 4.9097 - val_loss: 3.7774 - 141ms/epoch - 11ms/step
# Epoch 48/100
# 13/13 - 0s - loss: 4.8786 - val_loss: 3.7863 - 141ms/epoch - 11ms/step
# Epoch 49/100
# 13/13 - 0s - loss: 4.8650 - val_loss: 3.8082 - 125ms/epoch - 10ms/step
# Epoch 50/100
# 13/13 - 0s - loss: 4.8560 - val_loss: 3.8529 - 152ms/epoch - 12ms/step
# Epoch 51/100
# 13/13 - 0s - loss: 4.8489 - val_loss: 3.8937 - 132ms/epoch - 10ms/step
# Epoch 52/100
# 13/13 - 0s - loss: 4.8466 - val_loss: 3.9030 - 125ms/epoch - 10ms/step
# Epoch 53/100
# 13/13 - 0s - loss: 4.8445 - val_loss: 3.9171 - 141ms/epoch - 11ms/step
# Epoch 54/100
# 13/13 - 0s - loss: 4.8486 - val_loss: 3.9552 - 133ms/epoch - 10ms/step
# Epoch 55/100
# 13/13 - 0s - loss: 4.8448 - val_loss: 3.9769 - 125ms/epoch - 10ms/step
# Epoch 56/100
# 13/13 - 0s - loss: 4.8412 - val_loss: 3.9684 - 144ms/epoch - 11ms/step
# Epoch 57/100
# 13/13 - 0s - loss: 4.8416 - val_loss: 3.9657 - 126ms/epoch - 10ms/step
# Epoch 58/100
# 13/13 - 0s - loss: 4.8390 - val_loss: 3.9683 - 152ms/epoch - 12ms/step
# Epoch 59/100
# 13/13 - 0s - loss: 4.8375 - val_loss: 3.8536 - 143ms/epoch - 11ms/step
# Epoch 60/100
# 13/13 - 0s - loss: 4.8075 - val_loss: 3.8842 - 123ms/epoch - 9ms/step
# Epoch 61/100
# 13/13 - 0s - loss: 4.8080 - val_loss: 3.8895 - 135ms/epoch - 10ms/step
# Epoch 62/100
# 13/13 - 0s - loss: 4.8074 - val_loss: 3.9055 - 126ms/epoch - 10ms/step
# Epoch 63/100
# 13/13 - 0s - loss: 4.8030 - val_loss: 3.9475 - 141ms/epoch - 11ms/step
# Epoch 64/100
# 13/13 - 0s - loss: 4.8059 - val_loss: 3.9464 - 125ms/epoch - 10ms/step
# Epoch 65/100
# 13/13 - 0s - loss: 4.7823 - val_loss: 3.9198 - 150ms/epoch - 12ms/step
# Epoch 66/100
# 13/13 - 0s - loss: 4.7512 - val_loss: 3.9179 - 157ms/epoch - 12ms/step
# Epoch 67/100
# 13/13 - 0s - loss: 4.7512 - val_loss: 3.8219 - 130ms/epoch - 10ms/step
# Epoch 68/100
# 13/13 - 0s - loss: 4.8518 - val_loss: 3.9307 - 146ms/epoch - 11ms/step
# Epoch 69/100
# 13/13 - 0s - loss: 4.7449 - val_loss: 4.0459 - 155ms/epoch - 12ms/step
# Epoch 70/100
# 13/13 - 0s - loss: 4.7102 - val_loss: 4.0710 - 154ms/epoch - 12ms/step
# Epoch 71/100
# 13/13 - 0s - loss: 4.7007 - val_loss: 4.0815 - 152ms/epoch - 12ms/step
# Epoch 72/100
# 13/13 - 0s - loss: 4.7108 - val_loss: 4.0385 - 160ms/epoch - 12ms/step
# Epoch 73/100
# 13/13 - 0s - loss: 4.7032 - val_loss: 4.1488 - 174ms/epoch - 13ms/step
# Epoch 74/100
# 13/13 - 0s - loss: 4.6668 - val_loss: 4.0507 - 163ms/epoch - 13ms/step
# Epoch 75/100
# 13/13 - 0s - loss: 4.6926 - val_loss: 4.0781 - 160ms/epoch - 12ms/step
# Epoch 76/100
# 13/13 - 0s - loss: 4.6177 - val_loss: 4.0019 - 152ms/epoch - 12ms/step
# Epoch 77/100
# 13/13 - 0s - loss: 4.6402 - val_loss: 3.9628 - 156ms/epoch - 12ms/step
# Epoch 78/100
# 13/13 - 0s - loss: 4.5544 - val_loss: 3.9682 - 163ms/epoch - 13ms/step
# Epoch 79/100
# 13/13 - 0s - loss: 4.5707 - val_loss: 3.9958 - 173ms/epoch - 13ms/step
# Epoch 80/100
# 13/13 - 0s - loss: 4.5431 - val_loss: 3.9469 - 153ms/epoch - 12ms/step
# Epoch 81/100
# 13/13 - 0s - loss: 4.5485 - val_loss: 4.1008 - 148ms/epoch - 11ms/step
# Epoch 82/100
# 13/13 - 0s - loss: 4.5438 - val_loss: 4.1466 - 144ms/epoch - 11ms/step
# Epoch 83/100
# 13/13 - 0s - loss: 4.5235 - val_loss: 4.0438 - 156ms/epoch - 12ms/step
# Epoch 84/100
# 13/13 - 0s - loss: 4.5125 - val_loss: 4.0032 - 147ms/epoch - 11ms/step
# Epoch 85/100
# 13/13 - 0s - loss: 4.5059 - val_loss: 4.0851 - 160ms/epoch - 12ms/step
# Epoch 86/100
# 13/13 - 0s - loss: 4.4916 - val_loss: 4.0316 - 142ms/epoch - 11ms/step
# Epoch 87/100
# 13/13 - 0s - loss: 4.4522 - val_loss: 4.0310 - 131ms/epoch - 10ms/step
# Epoch 88/100
# 13/13 - 0s - loss: 4.4868 - val_loss: 4.0374 - 146ms/epoch - 11ms/step
# Epoch 89/100
# 13/13 - 0s - loss: 4.4799 - val_loss: 4.0480 - 141ms/epoch - 11ms/step
# Epoch 90/100
# 13/13 - 0s - loss: 4.4738 - val_loss: 4.0455 - 157ms/epoch - 12ms/step
# Epoch 91/100
# 13/13 - 0s - loss: 4.4746 - val_loss: 4.1236 - 148ms/epoch - 11ms/step
# Epoch 92/100
# 13/13 - 0s - loss: 4.4753 - val_loss: 4.0786 - 125ms/epoch - 10ms/step
# Epoch 93/100
# 13/13 - 0s - loss: 4.4691 - val_loss: 4.0672 - 125ms/epoch - 10ms/step
# Epoch 94/100
# 13/13 - 0s - loss: 4.4534 - val_loss: 4.0901 - 174ms/epoch - 13ms/step
# Epoch 95/100
# 13/13 - 0s - loss: 4.4610 - val_loss: 4.0458 - 181ms/epoch - 14ms/step
# Epoch 96/100
# 13/13 - 0s - loss: 4.4554 - val_loss: 4.0437 - 157ms/epoch - 12ms/step
# Epoch 97/100
# 13/13 - 0s - loss: 4.4274 - val_loss: 4.0878 - 142ms/epoch - 11ms/step
# Epoch 98/100
# 13/13 - 0s - loss: 4.4304 - val_loss: 4.0299 - 135ms/epoch - 10ms/step
# Epoch 99/100
# 13/13 - 0s - loss: 4.4458 - val_loss: 4.1562 - 141ms/epoch - 11ms/step
# Epoch 100/100
# 13/13 - 0s - loss: 4.4204 - val_loss: 4.0357 - 130ms/epoch - 10ms/step
# Epoch 1/100
# 13/13 - 2s - loss: 71.7305 - val_loss: 71.1635 - 2s/epoch - 123ms/step
# Epoch 2/100
# 13/13 - 0s - loss: 69.6386 - val_loss: 69.1102 - 126ms/epoch - 10ms/step
# Epoch 3/100
# 13/13 - 0s - loss: 67.4080 - val_loss: 66.6564 - 130ms/epoch - 10ms/step
# Epoch 4/100
# 13/13 - 0s - loss: 64.7254 - val_loss: 63.4627 - 110ms/epoch - 8ms/step
# Epoch 5/100
# 13/13 - 0s - loss: 61.2345 - val_loss: 59.5012 - 113ms/epoch - 9ms/step
# Epoch 6/100
# 13/13 - 0s - loss: 57.5706 - val_loss: 56.2159 - 146ms/epoch - 11ms/step
# Epoch 7/100
# 13/13 - 0s - loss: 54.6015 - val_loss: 53.6800 - 152ms/epoch - 12ms/step
# Epoch 8/100
# 13/13 - 0s - loss: 52.2402 - val_loss: 51.5436 - 165ms/epoch - 13ms/step
# Epoch 9/100
# 13/13 - 0s - loss: 50.1376 - val_loss: 49.6311 - 181ms/epoch - 14ms/step
# Epoch 10/100
# 13/13 - 0s - loss: 48.2793 - val_loss: 47.8496 - 177ms/epoch - 14ms/step
# Epoch 11/100
# 13/13 - 0s - loss: 46.5135 - val_loss: 46.1359 - 151ms/epoch - 12ms/step
# Epoch 12/100
# 13/13 - 0s - loss: 44.8382 - val_loss: 44.5121 - 158ms/epoch - 12ms/step
# Epoch 13/100
# 13/13 - 0s - loss: 43.2345 - val_loss: 42.9307 - 165ms/epoch - 13ms/step
# Epoch 14/100
# 13/13 - 0s - loss: 41.6690 - val_loss: 41.3833 - 145ms/epoch - 11ms/step
# Epoch 15/100
# 13/13 - 0s - loss: 40.1342 - val_loss: 39.8628 - 157ms/epoch - 12ms/step
# Epoch 16/100
# 13/13 - 0s - loss: 38.6243 - val_loss: 38.3645 - 154ms/epoch - 12ms/step
# Epoch 17/100
# 13/13 - 0s - loss: 37.1347 - val_loss: 36.8846 - 149ms/epoch - 11ms/step
# Epoch 18/100
# 13/13 - 0s - loss: 35.6622 - val_loss: 35.4204 - 151ms/epoch - 12ms/step
# Epoch 19/100
# 13/13 - 0s - loss: 34.2043 - val_loss: 33.9695 - 150ms/epoch - 12ms/step
# Epoch 20/100
# 13/13 - 0s - loss: 32.7589 - val_loss: 32.5303 - 151ms/epoch - 12ms/step
# Epoch 21/100
# 13/13 - 0s - loss: 31.3244 - val_loss: 31.1012 - 160ms/epoch - 12ms/step
# Epoch 22/100
# 13/13 - 0s - loss: 29.8996 - val_loss: 29.6812 - 158ms/epoch - 12ms/step
# Epoch 23/100
# 13/13 - 0s - loss: 28.4833 - val_loss: 28.2691 - 148ms/epoch - 11ms/step
# Epoch 24/100
# 13/13 - 0s - loss: 27.0746 - val_loss: 26.8642 - 133ms/epoch - 10ms/step
# Epoch 25/100
# 13/13 - 0s - loss: 25.6728 - val_loss: 25.4658 - 146ms/epoch - 11ms/step
# Epoch 26/100
# 13/13 - 0s - loss: 24.2771 - val_loss: 24.0733 - 130ms/epoch - 10ms/step
# Epoch 27/100
# 13/13 - 0s - loss: 22.8871 - val_loss: 22.6861 - 126ms/epoch - 10ms/step
# Epoch 28/100
# 13/13 - 0s - loss: 21.5022 - val_loss: 21.3038 - 141ms/epoch - 11ms/step
# Epoch 29/100
# 13/13 - 0s - loss: 20.1220 - val_loss: 19.9260 - 134ms/epoch - 10ms/step
# Epoch 30/100
# 13/13 - 0s - loss: 18.7461 - val_loss: 18.5523 - 133ms/epoch - 10ms/step
# Epoch 31/100
# 13/13 - 0s - loss: 17.3742 - val_loss: 17.1824 - 127ms/epoch - 10ms/step
# Epoch 32/100
# 13/13 - 0s - loss: 16.0227 - val_loss: 15.8265 - 125ms/epoch - 10ms/step
# Epoch 33/100
# 13/13 - 0s - loss: 14.7212 - val_loss: 14.4970 - 133ms/epoch - 10ms/step
# Epoch 34/100
# 13/13 - 0s - loss: 13.4422 - val_loss: 13.1526 - 126ms/epoch - 10ms/step
# Epoch 35/100
# 13/13 - 0s - loss: 12.1372 - val_loss: 11.8342 - 141ms/epoch - 11ms/step
# Epoch 36/100
# 13/13 - 0s - loss: 10.8584 - val_loss: 10.6118 - 140ms/epoch - 11ms/step
# Epoch 37/100
# 13/13 - 0s - loss: 9.6450 - val_loss: 9.4744 - 134ms/epoch - 10ms/step
# Epoch 38/100
# 13/13 - 0s - loss: 8.5171 - val_loss: 8.4180 - 141ms/epoch - 11ms/step
# Epoch 39/100
# 13/13 - 0s - loss: 7.5009 - val_loss: 7.5655 - 134ms/epoch - 10ms/step
# Epoch 40/100
# 13/13 - 0s - loss: 6.7330 - val_loss: 6.8845 - 125ms/epoch - 10ms/step
# Epoch 41/100
# 13/13 - 0s - loss: 6.1241 - val_loss: 6.3846 - 126ms/epoch - 10ms/step
# Epoch 42/100
# 13/13 - 0s - loss: 5.6563 - val_loss: 5.9711 - 125ms/epoch - 10ms/step
# Epoch 43/100
# 13/13 - 0s - loss: 5.3072 - val_loss: 5.6180 - 126ms/epoch - 10ms/step
# Epoch 44/100
# 13/13 - 0s - loss: 5.0581 - val_loss: 5.3541 - 125ms/epoch - 10ms/step
# Epoch 45/100
# 13/13 - 0s - loss: 4.9034 - val_loss: 5.1487 - 128ms/epoch - 10ms/step
# Epoch 46/100
# 13/13 - 0s - loss: 4.8063 - val_loss: 5.0058 - 146ms/epoch - 11ms/step
# Epoch 47/100
# 13/13 - 0s - loss: 4.7650 - val_loss: 4.8894 - 136ms/epoch - 10ms/step
# Epoch 48/100
# 13/13 - 0s - loss: 4.7045 - val_loss: 4.8324 - 125ms/epoch - 10ms/step
# Epoch 49/100
# 13/13 - 0s - loss: 4.6850 - val_loss: 4.7791 - 139ms/epoch - 11ms/step
# Epoch 50/100
# 13/13 - 0s - loss: 4.6659 - val_loss: 4.7524 - 123ms/epoch - 9ms/step
# Epoch 51/100
# 13/13 - 0s - loss: 4.6568 - val_loss: 4.7173 - 125ms/epoch - 10ms/step
# Epoch 52/100
# 13/13 - 0s - loss: 4.6556 - val_loss: 4.6988 - 125ms/epoch - 10ms/step
# Epoch 53/100
# 13/13 - 0s - loss: 4.6526 - val_loss: 4.6828 - 126ms/epoch - 10ms/step
# Epoch 54/100
# 13/13 - 0s - loss: 4.6526 - val_loss: 4.6647 - 141ms/epoch - 11ms/step
# Epoch 55/100
# 13/13 - 0s - loss: 4.6521 - val_loss: 4.6161 - 125ms/epoch - 10ms/step
# Epoch 56/100
# 13/13 - 0s - loss: 4.6369 - val_loss: 4.6861 - 119ms/epoch - 9ms/step
# Epoch 57/100
# 13/13 - 0s - loss: 4.6292 - val_loss: 4.6112 - 124ms/epoch - 10ms/step
# Epoch 58/100
# 13/13 - 0s - loss: 4.6250 - val_loss: 4.5652 - 126ms/epoch - 10ms/step
# Epoch 59/100
# 13/13 - 0s - loss: 4.6191 - val_loss: 4.5777 - 125ms/epoch - 10ms/step
# Epoch 60/100
# 13/13 - 0s - loss: 4.6107 - val_loss: 4.5665 - 140ms/epoch - 11ms/step
# Epoch 61/100
# 13/13 - 0s - loss: 4.6016 - val_loss: 4.5393 - 125ms/epoch - 10ms/step
# Epoch 62/100
# 13/13 - 0s - loss: 4.6105 - val_loss: 4.4915 - 152ms/epoch - 12ms/step
# Epoch 63/100
# 13/13 - 0s - loss: 4.5723 - val_loss: 4.4343 - 140ms/epoch - 11ms/step
# Epoch 64/100
# 13/13 - 0s - loss: 4.5673 - val_loss: 4.4404 - 142ms/epoch - 11ms/step
# Epoch 65/100
# 13/13 - 0s - loss: 4.5996 - val_loss: 4.4582 - 145ms/epoch - 11ms/step
# Epoch 66/100
# 13/13 - 0s - loss: 4.5827 - val_loss: 4.4991 - 166ms/epoch - 13ms/step
# Epoch 67/100
# 13/13 - 0s - loss: 4.5640 - val_loss: 4.4657 - 167ms/epoch - 13ms/step
# Epoch 68/100
# 13/13 - 0s - loss: 4.5706 - val_loss: 4.5169 - 167ms/epoch - 13ms/step
# Epoch 69/100
# 13/13 - 0s - loss: 4.5624 - val_loss: 4.4652 - 180ms/epoch - 14ms/step
# Epoch 70/100
# 13/13 - 0s - loss: 4.6212 - val_loss: 4.5755 - 157ms/epoch - 12ms/step
# Epoch 71/100
# 13/13 - 0s - loss: 4.5678 - val_loss: 4.4885 - 165ms/epoch - 13ms/step
# Epoch 72/100
# 13/13 - 0s - loss: 4.5644 - val_loss: 4.4513 - 143ms/epoch - 11ms/step
# Epoch 73/100
# 13/13 - 0s - loss: 4.5664 - val_loss: 4.5232 - 147ms/epoch - 11ms/step
# Epoch 74/100
# 13/13 - 0s - loss: 4.5683 - val_loss: 4.4854 - 143ms/epoch - 11ms/step
# Epoch 75/100
# 13/13 - 0s - loss: 4.5523 - val_loss: 4.4874 - 147ms/epoch - 11ms/step
# Epoch 76/100
# 13/13 - 0s - loss: 4.5325 - val_loss: 4.4886 - 156ms/epoch - 12ms/step
# Epoch 77/100
# 13/13 - 0s - loss: 4.5097 - val_loss: 4.4467 - 155ms/epoch - 12ms/step
# Epoch 78/100
# 13/13 - 0s - loss: 4.5231 - val_loss: 4.4493 - 136ms/epoch - 10ms/step
# Epoch 79/100
# 13/13 - 0s - loss: 4.4951 - val_loss: 4.5100 - 152ms/epoch - 12ms/step
# Epoch 80/100
# 13/13 - 0s - loss: 4.5143 - val_loss: 4.4119 - 127ms/epoch - 10ms/step
# Epoch 81/100
# 13/13 - 0s - loss: 4.5234 - val_loss: 4.6865 - 125ms/epoch - 10ms/step
# Epoch 82/100
# 13/13 - 0s - loss: 4.6145 - val_loss: 4.6422 - 126ms/epoch - 10ms/step
# Epoch 83/100
# 13/13 - 0s - loss: 4.4939 - val_loss: 4.4005 - 157ms/epoch - 12ms/step
# Epoch 84/100
# 13/13 - 0s - loss: 4.4342 - val_loss: 4.4060 - 120ms/epoch - 9ms/step
# Epoch 85/100
# 13/13 - 0s - loss: 4.4251 - val_loss: 4.3123 - 126ms/epoch - 10ms/step
# Epoch 86/100
# 13/13 - 0s - loss: 4.3990 - val_loss: 4.4354 - 125ms/epoch - 10ms/step
# Epoch 87/100
# 13/13 - 0s - loss: 4.4287 - val_loss: 4.3475 - 126ms/epoch - 10ms/step
# Epoch 88/100
# 13/13 - 0s - loss: 4.3770 - val_loss: 4.2974 - 130ms/epoch - 10ms/step
# Epoch 89/100
# 13/13 - 0s - loss: 4.3940 - val_loss: 4.3257 - 125ms/epoch - 10ms/step
# Epoch 90/100
# 13/13 - 0s - loss: 4.4176 - val_loss: 4.3713 - 125ms/epoch - 10ms/step
# Epoch 91/100
# 13/13 - 0s - loss: 4.4064 - val_loss: 4.2872 - 125ms/epoch - 10ms/step
# Epoch 92/100
# 13/13 - 0s - loss: 4.4135 - val_loss: 4.2747 - 149ms/epoch - 11ms/step
# Epoch 93/100
# 13/13 - 0s - loss: 4.3948 - val_loss: 4.4164 - 125ms/epoch - 10ms/step
# Epoch 94/100
# 13/13 - 0s - loss: 4.3946 - val_loss: 4.3003 - 125ms/epoch - 10ms/step
# Epoch 95/100
# 13/13 - 0s - loss: 4.4011 - val_loss: 4.3309 - 126ms/epoch - 10ms/step
# Epoch 96/100
# 13/13 - 0s - loss: 4.4283 - val_loss: 4.3508 - 124ms/epoch - 10ms/step
# Epoch 97/100
# 13/13 - 0s - loss: 4.3590 - val_loss: 4.3016 - 125ms/epoch - 10ms/step
# Epoch 98/100
# 13/13 - 0s - loss: 4.3777 - val_loss: 4.2861 - 126ms/epoch - 10ms/step
# Epoch 99/100
# 13/13 - 0s - loss: 4.3633 - val_loss: 4.3177 - 126ms/epoch - 10ms/step
# Epoch 100/100
# 13/13 - 0s - loss: 4.3573 - val_loss: 4.2760 - 152ms/epoch - 12ms/step
# Epoch 1/100
# 13/13 - 2s - loss: 71.7596 - val_loss: 69.1735 - 2s/epoch - 129ms/step
# Epoch 2/100
# 13/13 - 0s - loss: 69.6925 - val_loss: 67.0200 - 130ms/epoch - 10ms/step
# Epoch 3/100
# 13/13 - 0s - loss: 67.4619 - val_loss: 64.4368 - 132ms/epoch - 10ms/step
# Epoch 4/100
# 13/13 - 0s - loss: 64.5882 - val_loss: 61.0261 - 141ms/epoch - 11ms/step
# Epoch 5/100
# 13/13 - 0s - loss: 61.0767 - val_loss: 57.4790 - 137ms/epoch - 11ms/step
# Epoch 6/100
# 13/13 - 0s - loss: 57.5173 - val_loss: 54.0578 - 147ms/epoch - 11ms/step
# Epoch 7/100
# 13/13 - 0s - loss: 54.3573 - val_loss: 51.3554 - 149ms/epoch - 11ms/step
# Epoch 8/100
# 13/13 - 0s - loss: 51.8275 - val_loss: 49.1273 - 161ms/epoch - 12ms/step
# Epoch 9/100
# 13/13 - 0s - loss: 49.6919 - val_loss: 47.0943 - 141ms/epoch - 11ms/step
# Epoch 10/100
# 13/13 - 0s - loss: 47.7323 - val_loss: 45.2636 - 159ms/epoch - 12ms/step
# Epoch 11/100
# 13/13 - 0s - loss: 45.9414 - val_loss: 43.5571 - 155ms/epoch - 12ms/step
# Epoch 12/100
# 13/13 - 0s - loss: 44.2553 - val_loss: 41.9056 - 154ms/epoch - 12ms/step
# Epoch 13/100
# 13/13 - 0s - loss: 42.6217 - val_loss: 40.2964 - 146ms/epoch - 11ms/step
# Epoch 14/100
# 13/13 - 0s - loss: 41.0273 - val_loss: 38.7205 - 154ms/epoch - 12ms/step
# Epoch 15/100
# 13/13 - 0s - loss: 39.4633 - val_loss: 37.1714 - 172ms/epoch - 13ms/step
# Epoch 16/100
# 13/13 - 0s - loss: 37.9243 - val_loss: 35.6443 - 140ms/epoch - 11ms/step
# Epoch 17/100
# 13/13 - 0s - loss: 36.4055 - val_loss: 34.1357 - 140ms/epoch - 11ms/step
# Epoch 18/100
# 13/13 - 0s - loss: 34.9039 - val_loss: 32.6427 - 152ms/epoch - 12ms/step
# Epoch 19/100
# 13/13 - 0s - loss: 33.4170 - val_loss: 31.1631 - 142ms/epoch - 11ms/step
# Epoch 20/100
# 13/13 - 0s - loss: 31.9427 - val_loss: 29.6953 - 127ms/epoch - 10ms/step
# Epoch 21/100
# 13/13 - 0s - loss: 30.4794 - val_loss: 28.2377 - 144ms/epoch - 11ms/step
# Epoch 22/100
# 13/13 - 0s - loss: 29.0259 - val_loss: 26.7892 - 138ms/epoch - 11ms/step
# Epoch 23/100
# 13/13 - 0s - loss: 27.5810 - val_loss: 25.3488 - 141ms/epoch - 11ms/step
# Epoch 24/100
# 13/13 - 0s - loss: 26.1439 - val_loss: 23.9157 - 130ms/epoch - 10ms/step
# Epoch 25/100
# 13/13 - 0s - loss: 24.7137 - val_loss: 22.4892 - 141ms/epoch - 11ms/step
# Epoch 26/100
# 13/13 - 0s - loss: 23.2898 - val_loss: 21.0686 - 125ms/epoch - 10ms/step
# Epoch 27/100
# 13/13 - 0s - loss: 21.8716 - val_loss: 19.6534 - 126ms/epoch - 10ms/step
# Epoch 28/100
# 13/13 - 0s - loss: 20.4586 - val_loss: 18.2432 - 138ms/epoch - 11ms/step
# Epoch 29/100
# 13/13 - 0s - loss: 19.0504 - val_loss: 16.8375 - 126ms/epoch - 10ms/step
# Epoch 30/100
# 13/13 - 0s - loss: 17.6515 - val_loss: 15.4391 - 141ms/epoch - 11ms/step
# Epoch 31/100
# 13/13 - 0s - loss: 16.2903 - val_loss: 14.0879 - 133ms/epoch - 10ms/step
# Epoch 32/100
# 13/13 - 0s - loss: 14.9831 - val_loss: 12.7311 - 125ms/epoch - 10ms/step
# Epoch 33/100
# 13/13 - 0s - loss: 13.6743 - val_loss: 11.3734 - 157ms/epoch - 12ms/step
# Epoch 34/100
# 13/13 - 0s - loss: 12.3758 - val_loss: 10.0214 - 125ms/epoch - 10ms/step
# Epoch 35/100
# 13/13 - 0s - loss: 11.1420 - val_loss: 8.7407 - 117ms/epoch - 9ms/step
# Epoch 36/100
# 13/13 - 0s - loss: 10.0112 - val_loss: 7.5139 - 126ms/epoch - 10ms/step
# Epoch 37/100
# 13/13 - 0s - loss: 8.9243 - val_loss: 6.5316 - 125ms/epoch - 10ms/step
# Epoch 38/100
# 13/13 - 0s - loss: 7.9381 - val_loss: 5.7302 - 125ms/epoch - 10ms/step
# Epoch 39/100
# 13/13 - 0s - loss: 7.1215 - val_loss: 5.1929 - 134ms/epoch - 10ms/step
# Epoch 40/100
# 13/13 - 0s - loss: 6.4703 - val_loss: 4.8306 - 127ms/epoch - 10ms/step
# Epoch 41/100
# 13/13 - 0s - loss: 5.9502 - val_loss: 4.5561 - 125ms/epoch - 10ms/step
# Epoch 42/100
# 13/13 - 0s - loss: 5.5369 - val_loss: 4.4123 - 141ms/epoch - 11ms/step
# Epoch 43/100
# 13/13 - 0s - loss: 5.2369 - val_loss: 4.3328 - 143ms/epoch - 11ms/step
# Epoch 44/100
# 13/13 - 0s - loss: 5.0185 - val_loss: 4.2995 - 125ms/epoch - 10ms/step
# Epoch 45/100
# 13/13 - 0s - loss: 4.9115 - val_loss: 4.2729 - 126ms/epoch - 10ms/step
# Epoch 46/100
# 13/13 - 0s - loss: 4.8264 - val_loss: 4.2812 - 125ms/epoch - 10ms/step
# Epoch 47/100
# 13/13 - 0s - loss: 4.7850 - val_loss: 4.3044 - 121ms/epoch - 9ms/step
# Epoch 48/100
# 13/13 - 0s - loss: 4.7530 - val_loss: 4.3420 - 133ms/epoch - 10ms/step
# Epoch 49/100
# 13/13 - 0s - loss: 4.7231 - val_loss: 4.3682 - 118ms/epoch - 9ms/step
# Epoch 50/100
# 13/13 - 0s - loss: 4.7168 - val_loss: 4.4079 - 125ms/epoch - 10ms/step
# Epoch 51/100
# 13/13 - 0s - loss: 4.7103 - val_loss: 4.4043 - 116ms/epoch - 9ms/step
# Epoch 52/100
# 13/13 - 0s - loss: 4.7104 - val_loss: 4.4065 - 125ms/epoch - 10ms/step
# Epoch 53/100
# 13/13 - 0s - loss: 4.7118 - val_loss: 4.4202 - 141ms/epoch - 11ms/step
# Epoch 54/100
# 13/13 - 0s - loss: 4.7112 - val_loss: 4.4137 - 167ms/epoch - 13ms/step
# Epoch 55/100
# 13/13 - 0s - loss: 4.7111 - val_loss: 4.4002 - 110ms/epoch - 8ms/step
# Epoch 56/100
# 13/13 - 0s - loss: 4.7101 - val_loss: 4.4025 - 141ms/epoch - 11ms/step
# Epoch 57/100
# 13/13 - 0s - loss: 4.7104 - val_loss: 4.4063 - 134ms/epoch - 10ms/step
# Epoch 58/100
# 13/13 - 0s - loss: 4.7119 - val_loss: 4.4079 - 160ms/epoch - 12ms/step
# Epoch 59/100
# 13/13 - 0s - loss: 4.7120 - val_loss: 4.3995 - 146ms/epoch - 11ms/step
# Epoch 60/100
# 13/13 - 0s - loss: 4.7113 - val_loss: 4.4084 - 136ms/epoch - 10ms/step
# Epoch 61/100
# 13/13 - 0s - loss: 4.7122 - val_loss: 4.3906 - 165ms/epoch - 13ms/step
# Epoch 62/100
# 13/13 - 0s - loss: 4.7029 - val_loss: 4.3865 - 150ms/epoch - 12ms/step
# Epoch 63/100
# 13/13 - 0s - loss: 4.7073 - val_loss: 4.3604 - 151ms/epoch - 12ms/step
# Epoch 64/100
# 13/13 - 0s - loss: 4.7130 - val_loss: 4.4258 - 150ms/epoch - 12ms/step
# Epoch 65/100
# 13/13 - 0s - loss: 4.7087 - val_loss: 4.4297 - 152ms/epoch - 12ms/step
# Epoch 66/100
# 13/13 - 0s - loss: 4.7101 - val_loss: 4.4275 - 132ms/epoch - 10ms/step
# Epoch 67/100
# 13/13 - 0s - loss: 4.7102 - val_loss: 4.4345 - 140ms/epoch - 11ms/step
# Epoch 68/100
# 13/13 - 0s - loss: 4.7134 - val_loss: 4.4437 - 158ms/epoch - 12ms/step
# Epoch 69/100
# 13/13 - 0s - loss: 4.7041 - val_loss: 4.4018 - 145ms/epoch - 11ms/step
# Epoch 70/100
# 13/13 - 0s - loss: 4.7077 - val_loss: 4.4016 - 141ms/epoch - 11ms/step
# Epoch 71/100
# 13/13 - 0s - loss: 4.7267 - val_loss: 4.4678 - 150ms/epoch - 12ms/step
# Epoch 72/100
# 13/13 - 0s - loss: 4.7067 - val_loss: 4.4241 - 143ms/epoch - 11ms/step
# Epoch 73/100
# 13/13 - 0s - loss: 4.6891 - val_loss: 4.4246 - 154ms/epoch - 12ms/step
# Epoch 74/100
# 13/13 - 0s - loss: 4.6870 - val_loss: 4.4164 - 147ms/epoch - 11ms/step
# Epoch 75/100
# 13/13 - 0s - loss: 4.6741 - val_loss: 4.4235 - 157ms/epoch - 12ms/step
# Epoch 76/100
# 13/13 - 0s - loss: 4.6893 - val_loss: 4.4005 - 141ms/epoch - 11ms/step
# Epoch 77/100
# 13/13 - 0s - loss: 4.6782 - val_loss: 4.4415 - 125ms/epoch - 10ms/step
# Epoch 78/100
# 13/13 - 0s - loss: 4.6791 - val_loss: 4.4094 - 118ms/epoch - 9ms/step
# Epoch 79/100
# 13/13 - 0s - loss: 4.6737 - val_loss: 4.4485 - 141ms/epoch - 11ms/step
# Epoch 80/100
# 13/13 - 0s - loss: 4.6779 - val_loss: 4.4214 - 110ms/epoch - 8ms/step
# Epoch 81/100
# 13/13 - 0s - loss: 4.6766 - val_loss: 4.4276 - 136ms/epoch - 10ms/step
# Epoch 82/100
# 13/13 - 0s - loss: 4.6969 - val_loss: 4.3266 - 122ms/epoch - 9ms/step
# Epoch 83/100
# 13/13 - 0s - loss: 4.6716 - val_loss: 4.4289 - 140ms/epoch - 11ms/step
# Epoch 84/100
# 13/13 - 0s - loss: 4.6768 - val_loss: 4.4102 - 126ms/epoch - 10ms/step
# Epoch 85/100
# 13/13 - 0s - loss: 4.6651 - val_loss: 4.4209 - 129ms/epoch - 10ms/step
# Epoch 86/100
# 13/13 - 0s - loss: 4.6658 - val_loss: 4.4043 - 117ms/epoch - 9ms/step
# Epoch 87/100
# 13/13 - 0s - loss: 4.6634 - val_loss: 4.3804 - 125ms/epoch - 10ms/step
# Epoch 88/100
# 13/13 - 0s - loss: 4.6563 - val_loss: 4.4034 - 129ms/epoch - 10ms/step
# Epoch 89/100
# 13/13 - 0s - loss: 4.6490 - val_loss: 4.3405 - 122ms/epoch - 9ms/step
# Epoch 90/100
# 13/13 - 0s - loss: 4.6768 - val_loss: 4.4599 - 128ms/epoch - 10ms/step
# Epoch 91/100
# 13/13 - 0s - loss: 4.6597 - val_loss: 4.3900 - 126ms/epoch - 10ms/step
# Epoch 92/100
# 13/13 - 0s - loss: 4.6543 - val_loss: 4.3699 - 126ms/epoch - 10ms/step
# Epoch 93/100
# 13/13 - 0s - loss: 4.6604 - val_loss: 4.3870 - 125ms/epoch - 10ms/step
# Epoch 94/100
# 13/13 - 0s - loss: 4.6674 - val_loss: 4.4211 - 134ms/epoch - 10ms/step
# Epoch 95/100
# 13/13 - 0s - loss: 4.6550 - val_loss: 4.3849 - 142ms/epoch - 11ms/step
# Epoch 96/100
# 13/13 - 0s - loss: 4.6489 - val_loss: 4.3928 - 125ms/epoch - 10ms/step
# Epoch 97/100
# 13/13 - 0s - loss: 4.6500 - val_loss: 4.3781 - 125ms/epoch - 10ms/step
# Epoch 98/100
# 13/13 - 0s - loss: 4.6502 - val_loss: 4.3892 - 133ms/epoch - 10ms/step
# Epoch 99/100
# 13/13 - 0s - loss: 4.6453 - val_loss: 4.4115 - 139ms/epoch - 11ms/step
# Epoch 100/100
# 13/13 - 0s - loss: 4.6555 - val_loss: 4.3407 - 116ms/epoch - 9ms/step
# Epoch 1/100
# 13/13 - 2s - loss: 69.5227 - val_loss: 69.8049 - 2s/epoch - 125ms/step
# Epoch 2/100
# 13/13 - 0s - loss: 67.4472 - val_loss: 67.6282 - 160ms/epoch - 12ms/step
# Epoch 3/100
# 13/13 - 0s - loss: 65.1125 - val_loss: 65.1429 - 141ms/epoch - 11ms/step
# Epoch 4/100
# 13/13 - 0s - loss: 62.1880 - val_loss: 62.0306 - 136ms/epoch - 10ms/step
# Epoch 5/100
# 13/13 - 0s - loss: 58.6761 - val_loss: 58.5259 - 148ms/epoch - 11ms/step
# Epoch 6/100
# 13/13 - 0s - loss: 55.3878 - val_loss: 55.5001 - 154ms/epoch - 12ms/step
# Epoch 7/100
# 13/13 - 0s - loss: 52.6427 - val_loss: 52.8026 - 163ms/epoch - 13ms/step
# Epoch 8/100
# 13/13 - 0s - loss: 50.2589 - val_loss: 50.7168 - 148ms/epoch - 11ms/step
# Epoch 9/100
# 13/13 - 0s - loss: 48.3729 - val_loss: 48.9521 - 150ms/epoch - 12ms/step
# Epoch 10/100
# 13/13 - 0s - loss: 46.6427 - val_loss: 47.2685 - 140ms/epoch - 11ms/step
# Epoch 11/100
# 13/13 - 0s - loss: 44.9735 - val_loss: 45.6194 - 139ms/epoch - 11ms/step
# Epoch 12/100
# 13/13 - 0s - loss: 43.3281 - val_loss: 43.9752 - 142ms/epoch - 11ms/step
# Epoch 13/100
# 13/13 - 0s - loss: 41.7206 - val_loss: 42.4038 - 136ms/epoch - 10ms/step
# Epoch 14/100
# 13/13 - 0s - loss: 40.1663 - val_loss: 40.8656 - 157ms/epoch - 12ms/step
# Epoch 15/100
# 13/13 - 0s - loss: 38.6385 - val_loss: 39.3504 - 137ms/epoch - 11ms/step
# Epoch 16/100
# 13/13 - 0s - loss: 37.1319 - val_loss: 37.8540 - 125ms/epoch - 10ms/step
# Epoch 17/100
# 13/13 - 0s - loss: 35.6426 - val_loss: 36.3734 - 125ms/epoch - 10ms/step
# Epoch 18/100
# 13/13 - 0s - loss: 34.1679 - val_loss: 34.9060 - 115ms/epoch - 9ms/step
# Epoch 19/100
# 13/13 - 0s - loss: 32.7057 - val_loss: 33.4500 - 120ms/epoch - 9ms/step
# Epoch 20/100
# 13/13 - 0s - loss: 31.2542 - val_loss: 32.0040 - 141ms/epoch - 11ms/step
# Epoch 21/100
# 13/13 - 0s - loss: 29.8121 - val_loss: 30.5668 - 157ms/epoch - 12ms/step
# Epoch 22/100
# 13/13 - 0s - loss: 28.3783 - val_loss: 29.1372 - 172ms/epoch - 13ms/step
# Epoch 23/100
# 13/13 - 0s - loss: 26.9518 - val_loss: 27.7145 - 146ms/epoch - 11ms/step
# Epoch 24/100
# 13/13 - 0s - loss: 25.5319 - val_loss: 26.2981 - 157ms/epoch - 12ms/step
# Epoch 25/100
# 13/13 - 0s - loss: 24.1180 - val_loss: 24.8872 - 126ms/epoch - 10ms/step
# Epoch 26/100
# 13/13 - 0s - loss: 22.7094 - val_loss: 23.4814 - 118ms/epoch - 9ms/step
# Epoch 27/100
# 13/13 - 0s - loss: 21.3056 - val_loss: 22.0802 - 125ms/epoch - 10ms/step
# Epoch 28/100
# 13/13 - 0s - loss: 19.9063 - val_loss: 20.6833 - 130ms/epoch - 10ms/step
# Epoch 29/100
# 13/13 - 0s - loss: 18.5111 - val_loss: 19.2903 - 144ms/epoch - 11ms/step
# Epoch 30/100
# 13/13 - 0s - loss: 17.1197 - val_loss: 17.9249 - 173ms/epoch - 13ms/step
# Epoch 31/100
# 13/13 - 0s - loss: 15.7317 - val_loss: 16.7121 - 141ms/epoch - 11ms/step
# Epoch 32/100
# 13/13 - 0s - loss: 14.3470 - val_loss: 15.5020 - 127ms/epoch - 10ms/step
# Epoch 33/100
# 13/13 - 0s - loss: 12.9652 - val_loss: 14.2945 - 125ms/epoch - 10ms/step
# Epoch 34/100
# 13/13 - 0s - loss: 11.6012 - val_loss: 13.1501 - 127ms/epoch - 10ms/step
# Epoch 35/100
# 13/13 - 0s - loss: 10.2827 - val_loss: 12.0906 - 115ms/epoch - 9ms/step
# Epoch 36/100
# 13/13 - 0s - loss: 9.0696 - val_loss: 11.0235 - 110ms/epoch - 8ms/step
# Epoch 37/100
# 13/13 - 0s - loss: 7.9158 - val_loss: 9.9973 - 140ms/epoch - 11ms/step
# Epoch 38/100
# 13/13 - 0s - loss: 6.9434 - val_loss: 9.1595 - 125ms/epoch - 10ms/step
# Epoch 39/100
# 13/13 - 0s - loss: 6.1896 - val_loss: 8.4960 - 129ms/epoch - 10ms/step
# Epoch 40/100
# 13/13 - 0s - loss: 5.6276 - val_loss: 7.9964 - 122ms/epoch - 9ms/step
# Epoch 41/100
# 13/13 - 0s - loss: 5.1500 - val_loss: 7.6328 - 125ms/epoch - 10ms/step
# Epoch 42/100
# 13/13 - 0s - loss: 4.8387 - val_loss: 7.2990 - 124ms/epoch - 10ms/step
# Epoch 43/100
# 13/13 - 0s - loss: 4.6143 - val_loss: 7.0307 - 129ms/epoch - 10ms/step
# Epoch 44/100
# 13/13 - 0s - loss: 4.4696 - val_loss: 6.8090 - 122ms/epoch - 9ms/step
# Epoch 45/100
# 13/13 - 0s - loss: 4.3805 - val_loss: 6.6571 - 125ms/epoch - 10ms/step
# Epoch 46/100
# 13/13 - 0s - loss: 4.3300 - val_loss: 6.5639 - 129ms/epoch - 10ms/step
# Epoch 47/100
# 13/13 - 0s - loss: 4.3010 - val_loss: 6.4758 - 124ms/epoch - 10ms/step
# Epoch 48/100
# 13/13 - 0s - loss: 4.2794 - val_loss: 6.4250 - 123ms/epoch - 9ms/step
# Epoch 49/100
# 13/13 - 0s - loss: 4.2716 - val_loss: 6.3919 - 116ms/epoch - 9ms/step
# Epoch 50/100
# 13/13 - 0s - loss: 4.2674 - val_loss: 6.3411 - 116ms/epoch - 9ms/step
# Epoch 51/100
# 13/13 - 0s - loss: 4.2552 - val_loss: 6.3128 - 140ms/epoch - 11ms/step
# Epoch 52/100
# 13/13 - 0s - loss: 4.2526 - val_loss: 6.3122 - 146ms/epoch - 11ms/step
# Epoch 53/100
# 13/13 - 0s - loss: 4.2524 - val_loss: 6.3045 - 144ms/epoch - 11ms/step
# Epoch 54/100
# 13/13 - 0s - loss: 4.2527 - val_loss: 6.2920 - 159ms/epoch - 12ms/step
# Epoch 55/100
# 13/13 - 0s - loss: 4.2527 - val_loss: 6.2985 - 147ms/epoch - 11ms/step
# Epoch 56/100
# 13/13 - 0s - loss: 4.2529 - val_loss: 6.2737 - 152ms/epoch - 12ms/step
# Epoch 57/100
# 13/13 - 0s - loss: 4.2526 - val_loss: 6.2799 - 159ms/epoch - 12ms/step
# Epoch 58/100
# 13/13 - 0s - loss: 4.2512 - val_loss: 6.2693 - 144ms/epoch - 11ms/step
# Epoch 59/100
# 13/13 - 0s - loss: 4.2526 - val_loss: 6.2605 - 141ms/epoch - 11ms/step
# Epoch 60/100
# 13/13 - 0s - loss: 4.2563 - val_loss: 6.2818 - 158ms/epoch - 12ms/step
# Epoch 61/100
# 13/13 - 0s - loss: 4.2566 - val_loss: 6.2548 - 150ms/epoch - 12ms/step
# Epoch 62/100
# 13/13 - 0s - loss: 4.2550 - val_loss: 6.2748 - 144ms/epoch - 11ms/step
# Epoch 63/100
# 13/13 - 0s - loss: 4.2528 - val_loss: 6.2598 - 144ms/epoch - 11ms/step
# Epoch 64/100
# 13/13 - 0s - loss: 4.2531 - val_loss: 6.2642 - 140ms/epoch - 11ms/step
# Epoch 65/100
# 13/13 - 0s - loss: 4.2538 - val_loss: 6.2717 - 146ms/epoch - 11ms/step
# Epoch 66/100
# 13/13 - 0s - loss: 4.2602 - val_loss: 6.3204 - 140ms/epoch - 11ms/step
# Epoch 67/100
# 13/13 - 0s - loss: 4.2525 - val_loss: 6.3132 - 154ms/epoch - 12ms/step
# Epoch 68/100
# 13/13 - 0s - loss: 4.2521 - val_loss: 6.3089 - 129ms/epoch - 10ms/step
# Epoch 69/100
# 13/13 - 0s - loss: 4.2531 - val_loss: 6.2974 - 125ms/epoch - 10ms/step
# Epoch 70/100
# 13/13 - 0s - loss: 4.2569 - val_loss: 6.3144 - 143ms/epoch - 11ms/step
# Epoch 71/100
# 13/13 - 0s - loss: 4.2517 - val_loss: 6.3051 - 117ms/epoch - 9ms/step
# Epoch 72/100
# 13/13 - 0s - loss: 4.2526 - val_loss: 6.3004 - 110ms/epoch - 8ms/step
# Epoch 73/100
# 13/13 - 0s - loss: 4.2569 - val_loss: 6.2700 - 125ms/epoch - 10ms/step
# Epoch 74/100
# 13/13 - 0s - loss: 4.2525 - val_loss: 6.2774 - 133ms/epoch - 10ms/step
# Epoch 75/100
# 13/13 - 0s - loss: 4.2546 - val_loss: 6.2994 - 123ms/epoch - 9ms/step
# Epoch 76/100
# 13/13 - 0s - loss: 4.2543 - val_loss: 6.2817 - 125ms/epoch - 10ms/step
# Epoch 77/100
# 13/13 - 0s - loss: 4.2528 - val_loss: 6.2690 - 125ms/epoch - 10ms/step
# Epoch 78/100
# 13/13 - 0s - loss: 4.2530 - val_loss: 6.2777 - 141ms/epoch - 11ms/step
# Epoch 79/100
# 13/13 - 0s - loss: 4.2510 - val_loss: 6.2666 - 126ms/epoch - 10ms/step
# Epoch 80/100
# 13/13 - 0s - loss: 4.2517 - val_loss: 6.2623 - 125ms/epoch - 10ms/step
# Epoch 81/100
# 13/13 - 0s - loss: 4.2532 - val_loss: 6.2569 - 126ms/epoch - 10ms/step
# Epoch 82/100
# 13/13 - 0s - loss: 4.2528 - val_loss: 6.2552 - 114ms/epoch - 9ms/step
# Epoch 83/100
# 13/13 - 0s - loss: 4.2546 - val_loss: 6.2771 - 134ms/epoch - 10ms/step
# Epoch 84/100
# 13/13 - 0s - loss: 4.2544 - val_loss: 6.2568 - 138ms/epoch - 11ms/step
# Epoch 85/100
# 13/13 - 0s - loss: 4.2522 - val_loss: 6.2540 - 118ms/epoch - 9ms/step
# Epoch 86/100
# 13/13 - 0s - loss: 4.2532 - val_loss: 6.2914 - 136ms/epoch - 10ms/step
# Epoch 87/100
# 13/13 - 0s - loss: 4.2523 - val_loss: 6.2879 - 125ms/epoch - 10ms/step
# Epoch 88/100
# 13/13 - 0s - loss: 4.2535 - val_loss: 6.2978 - 121ms/epoch - 9ms/step
# Epoch 89/100
# 13/13 - 0s - loss: 4.2537 - val_loss: 6.2582 - 113ms/epoch - 9ms/step
# Epoch 90/100
# 13/13 - 0s - loss: 4.2571 - val_loss: 6.2543 - 132ms/epoch - 10ms/step
# Epoch 91/100
# 13/13 - 0s - loss: 4.2538 - val_loss: 6.2599 - 125ms/epoch - 10ms/step
# Epoch 92/100
# 13/13 - 0s - loss: 4.2542 - val_loss: 6.3011 - 125ms/epoch - 10ms/step
# Epoch 93/100
# 13/13 - 0s - loss: 4.2520 - val_loss: 6.3060 - 125ms/epoch - 10ms/step
# Epoch 94/100
# 13/13 - 0s - loss: 4.2535 - val_loss: 6.3013 - 133ms/epoch - 10ms/step
# Epoch 95/100
# 13/13 - 0s - loss: 4.2532 - val_loss: 6.2880 - 133ms/epoch - 10ms/step
# Epoch 96/100
# 13/13 - 0s - loss: 4.2567 - val_loss: 6.3190 - 118ms/epoch - 9ms/step
# Epoch 97/100
# 13/13 - 0s - loss: 4.2564 - val_loss: 6.2711 - 125ms/epoch - 10ms/step
# Epoch 98/100
# 13/13 - 0s - loss: 4.2521 - val_loss: 6.2691 - 120ms/epoch - 9ms/step
# Epoch 99/100
# 13/13 - 0s - loss: 4.2610 - val_loss: 6.3067 - 125ms/epoch - 10ms/step
# Epoch 100/100
# 13/13 - 0s - loss: 4.2521 - val_loss: 6.3019 - 111ms/epoch - 9ms/step
# Epoch 1/100
# 13/13 - 2s - loss: 70.7247 - val_loss: 70.4787 - 2s/epoch - 134ms/step
# Epoch 2/100
# 13/13 - 0s - loss: 68.8173 - val_loss: 68.4887 - 146ms/epoch - 11ms/step
# Epoch 3/100
# 13/13 - 0s - loss: 66.6699 - val_loss: 66.1125 - 135ms/epoch - 10ms/step
# Epoch 4/100
# 13/13 - 0s - loss: 63.9609 - val_loss: 62.9159 - 144ms/epoch - 11ms/step
# Epoch 5/100
# 13/13 - 0s - loss: 60.6724 - val_loss: 59.6797 - 150ms/epoch - 12ms/step
# Epoch 6/100
# 13/13 - 0s - loss: 57.5349 - val_loss: 56.6594 - 168ms/epoch - 13ms/step
# Epoch 7/100
# 13/13 - 0s - loss: 54.6690 - val_loss: 54.0068 - 154ms/epoch - 12ms/step
# Epoch 8/100
# 13/13 - 0s - loss: 52.1706 - val_loss: 51.7838 - 134ms/epoch - 10ms/step
# Epoch 9/100
# 13/13 - 0s - loss: 50.1687 - val_loss: 49.9817 - 134ms/epoch - 10ms/step
# Epoch 10/100
# 13/13 - 0s - loss: 48.4134 - val_loss: 48.2751 - 117ms/epoch - 9ms/step
# Epoch 11/100
# 13/13 - 0s - loss: 46.7296 - val_loss: 46.5961 - 126ms/epoch - 10ms/step
# Epoch 12/100
# 13/13 - 0s - loss: 45.0322 - val_loss: 44.8890 - 128ms/epoch - 10ms/step
# Epoch 13/100
# 13/13 - 0s - loss: 43.3720 - val_loss: 43.3008 - 125ms/epoch - 10ms/step
# Epoch 14/100
# 13/13 - 0s - loss: 41.8033 - val_loss: 41.7480 - 125ms/epoch - 10ms/step
# Epoch 15/100
# 13/13 - 0s - loss: 40.2619 - val_loss: 40.2196 - 126ms/epoch - 10ms/step
# Epoch 16/100
# 13/13 - 0s - loss: 38.7431 - val_loss: 38.7118 - 142ms/epoch - 11ms/step
# Epoch 17/100
# 13/13 - 0s - loss: 37.2432 - val_loss: 37.2208 - 141ms/epoch - 11ms/step
# Epoch 18/100
# 13/13 - 0s - loss: 35.7589 - val_loss: 35.7443 - 111ms/epoch - 9ms/step
# Epoch 19/100
# 13/13 - 0s - loss: 34.2881 - val_loss: 34.2800 - 125ms/epoch - 10ms/step
# Epoch 20/100
# 13/13 - 0s - loss: 32.8288 - val_loss: 32.8264 - 118ms/epoch - 9ms/step
# Epoch 21/100
# 13/13 - 0s - loss: 31.3795 - val_loss: 31.3822 - 124ms/epoch - 10ms/step
# Epoch 22/100
# 13/13 - 0s - loss: 29.9391 - val_loss: 29.9462 - 110ms/epoch - 8ms/step
# Epoch 23/100
# 13/13 - 0s - loss: 28.5065 - val_loss: 28.5176 - 144ms/epoch - 11ms/step
# Epoch 24/100
# 13/13 - 0s - loss: 27.0810 - val_loss: 27.0955 - 135ms/epoch - 10ms/step
# Epoch 25/100
# 13/13 - 0s - loss: 25.6617 - val_loss: 25.6795 - 126ms/epoch - 10ms/step
# Epoch 26/100
# 13/13 - 0s - loss: 24.2481 - val_loss: 24.2688 - 125ms/epoch - 10ms/step
# Epoch 27/100
# 13/13 - 0s - loss: 22.8397 - val_loss: 22.8631 - 125ms/epoch - 10ms/step
# Epoch 28/100
# 13/13 - 0s - loss: 21.4360 - val_loss: 21.4618 - 117ms/epoch - 9ms/step
# Epoch 29/100
# 13/13 - 0s - loss: 20.0367 - val_loss: 20.0647 - 125ms/epoch - 10ms/step
# Epoch 30/100
# 13/13 - 0s - loss: 18.6413 - val_loss: 18.6714 - 102ms/epoch - 8ms/step
# Epoch 31/100
# 13/13 - 0s - loss: 17.2506 - val_loss: 17.2872 - 126ms/epoch - 10ms/step
# Epoch 32/100
# 13/13 - 0s - loss: 15.9096 - val_loss: 15.9271 - 132ms/epoch - 10ms/step
# Epoch 33/100
# 13/13 - 0s - loss: 14.5924 - val_loss: 14.5869 - 142ms/epoch - 11ms/step
# Epoch 34/100
# 13/13 - 0s - loss: 13.2915 - val_loss: 13.2470 - 125ms/epoch - 10ms/step
# Epoch 35/100
# 13/13 - 0s - loss: 12.0146 - val_loss: 11.9139 - 125ms/epoch - 10ms/step
# Epoch 36/100
# 13/13 - 0s - loss: 10.8006 - val_loss: 10.7003 - 125ms/epoch - 10ms/step
# Epoch 37/100
# 13/13 - 0s - loss: 9.6251 - val_loss: 9.5310 - 125ms/epoch - 10ms/step
# Epoch 38/100
# 13/13 - 0s - loss: 8.5273 - val_loss: 8.4013 - 125ms/epoch - 10ms/step
# Epoch 39/100
# 13/13 - 0s - loss: 7.6139 - val_loss: 7.3888 - 131ms/epoch - 10ms/step
# Epoch 40/100
# 13/13 - 0s - loss: 6.8999 - val_loss: 6.4907 - 111ms/epoch - 9ms/step
# Epoch 41/100
# 13/13 - 0s - loss: 6.3598 - val_loss: 5.7328 - 141ms/epoch - 11ms/step
# Epoch 42/100
# 13/13 - 0s - loss: 5.9468 - val_loss: 5.2200 - 126ms/epoch - 10ms/step
# Epoch 43/100
# 13/13 - 0s - loss: 5.6334 - val_loss: 4.8375 - 125ms/epoch - 10ms/step
# Epoch 44/100
# 13/13 - 0s - loss: 5.3919 - val_loss: 4.5607 - 134ms/epoch - 10ms/step
# Epoch 45/100
# 13/13 - 0s - loss: 5.1747 - val_loss: 4.3811 - 126ms/epoch - 10ms/step
# Epoch 46/100
# 13/13 - 0s - loss: 5.0330 - val_loss: 4.2834 - 130ms/epoch - 10ms/step
# Epoch 47/100
# 13/13 - 0s - loss: 4.9363 - val_loss: 4.2393 - 142ms/epoch - 11ms/step
# Epoch 48/100
# 13/13 - 0s - loss: 4.8511 - val_loss: 4.2204 - 164ms/epoch - 13ms/step
# Epoch 49/100
# 13/13 - 0s - loss: 4.8071 - val_loss: 4.2107 - 152ms/epoch - 12ms/step
# Epoch 50/100
# 13/13 - 0s - loss: 4.7753 - val_loss: 4.2163 - 145ms/epoch - 11ms/step
# Epoch 51/100
# 13/13 - 0s - loss: 4.7580 - val_loss: 4.2216 - 144ms/epoch - 11ms/step
# Epoch 52/100
# 13/13 - 0s - loss: 4.7507 - val_loss: 4.2265 - 141ms/epoch - 11ms/step
# Epoch 53/100
# 13/13 - 0s - loss: 4.7457 - val_loss: 4.2280 - 143ms/epoch - 11ms/step
# Epoch 54/100
# 13/13 - 0s - loss: 4.7457 - val_loss: 4.2264 - 137ms/epoch - 11ms/step
# Epoch 55/100
# 13/13 - 0s - loss: 4.7458 - val_loss: 4.2271 - 153ms/epoch - 12ms/step
# Epoch 56/100
# 13/13 - 0s - loss: 4.7467 - val_loss: 4.2269 - 148ms/epoch - 11ms/step
# Epoch 57/100
# 13/13 - 0s - loss: 4.7470 - val_loss: 4.2258 - 142ms/epoch - 11ms/step
# Epoch 58/100
# 13/13 - 0s - loss: 4.7495 - val_loss: 4.2254 - 143ms/epoch - 11ms/step
# Epoch 59/100
# 13/13 - 0s - loss: 4.7467 - val_loss: 4.2333 - 138ms/epoch - 11ms/step
# Epoch 60/100
# 13/13 - 0s - loss: 4.7504 - val_loss: 4.2271 - 151ms/epoch - 12ms/step
# Epoch 61/100
# 13/13 - 0s - loss: 4.7461 - val_loss: 4.2251 - 143ms/epoch - 11ms/step
# Epoch 62/100
# 13/13 - 0s - loss: 4.7466 - val_loss: 4.2264 - 149ms/epoch - 11ms/step
# Epoch 63/100
# 13/13 - 0s - loss: 4.7462 - val_loss: 4.2281 - 156ms/epoch - 12ms/step
# Epoch 64/100
# 13/13 - 0s - loss: 4.7461 - val_loss: 4.2264 - 136ms/epoch - 10ms/step
# Epoch 65/100
# 13/13 - 0s - loss: 4.7458 - val_loss: 4.2280 - 118ms/epoch - 9ms/step
# Epoch 66/100
# 13/13 - 0s - loss: 4.7451 - val_loss: 4.2246 - 125ms/epoch - 10ms/step
# Epoch 67/100
# 13/13 - 0s - loss: 4.7449 - val_loss: 4.2215 - 125ms/epoch - 10ms/step
# Epoch 68/100
# 13/13 - 0s - loss: 4.7368 - val_loss: 4.2557 - 126ms/epoch - 10ms/step
# Epoch 69/100
# 13/13 - 0s - loss: 4.7242 - val_loss: 4.2579 - 132ms/epoch - 10ms/step
# Epoch 70/100
# 13/13 - 0s - loss: 4.7206 - val_loss: 4.2572 - 125ms/epoch - 10ms/step
# Epoch 71/100
# 13/13 - 0s - loss: 4.7324 - val_loss: 4.2485 - 125ms/epoch - 10ms/step
# Epoch 72/100
# 13/13 - 0s - loss: 4.7171 - val_loss: 4.2532 - 134ms/epoch - 10ms/step
# Epoch 73/100
# 13/13 - 0s - loss: 4.7316 - val_loss: 4.2793 - 132ms/epoch - 10ms/step
# Epoch 74/100
# 13/13 - 0s - loss: 4.7148 - val_loss: 4.3051 - 141ms/epoch - 11ms/step
# Epoch 75/100
# 13/13 - 0s - loss: 4.7085 - val_loss: 4.2955 - 114ms/epoch - 9ms/step
# Epoch 76/100
# 13/13 - 0s - loss: 4.7091 - val_loss: 4.2997 - 126ms/epoch - 10ms/step
# Epoch 77/100
# 13/13 - 0s - loss: 4.7025 - val_loss: 4.3027 - 133ms/epoch - 10ms/step
# Epoch 78/100
# 13/13 - 0s - loss: 4.6697 - val_loss: 4.3092 - 125ms/epoch - 10ms/step
# Epoch 79/100
# 13/13 - 0s - loss: 4.6860 - val_loss: 4.3103 - 113ms/epoch - 9ms/step
# Epoch 80/100
# 13/13 - 0s - loss: 4.6916 - val_loss: 4.3243 - 138ms/epoch - 11ms/step
# Epoch 81/100
# 13/13 - 0s - loss: 4.6671 - val_loss: 4.3071 - 131ms/epoch - 10ms/step
# Epoch 82/100
# 13/13 - 0s - loss: 4.6656 - val_loss: 4.3015 - 131ms/epoch - 10ms/step
# Epoch 83/100
# 13/13 - 0s - loss: 4.6625 - val_loss: 4.2974 - 136ms/epoch - 10ms/step
# Epoch 84/100
# 13/13 - 0s - loss: 4.6625 - val_loss: 4.3178 - 110ms/epoch - 8ms/step
# Epoch 85/100
# 13/13 - 0s - loss: 4.6621 - val_loss: 4.3037 - 117ms/epoch - 9ms/step
# Epoch 86/100
# 13/13 - 0s - loss: 4.6786 - val_loss: 4.3169 - 110ms/epoch - 8ms/step
# Epoch 87/100
# 13/13 - 0s - loss: 4.6472 - val_loss: 4.3074 - 112ms/epoch - 9ms/step
# Epoch 88/100
# 13/13 - 0s - loss: 4.6539 - val_loss: 4.3128 - 119ms/epoch - 9ms/step
# Epoch 89/100
# 13/13 - 0s - loss: 4.6638 - val_loss: 4.3032 - 132ms/epoch - 10ms/step
# Epoch 90/100
# 13/13 - 0s - loss: 4.6453 - val_loss: 4.3243 - 125ms/epoch - 10ms/step
# Epoch 91/100
# 13/13 - 0s - loss: 4.6513 - val_loss: 4.3227 - 126ms/epoch - 10ms/step
# Epoch 92/100
# 13/13 - 0s - loss: 4.6430 - val_loss: 4.3171 - 141ms/epoch - 11ms/step
# Epoch 93/100
# 13/13 - 0s - loss: 4.6472 - val_loss: 4.3191 - 120ms/epoch - 9ms/step
# Epoch 94/100
# 13/13 - 0s - loss: 4.6433 - val_loss: 4.2914 - 126ms/epoch - 10ms/step
# Epoch 95/100
# 13/13 - 0s - loss: 4.6463 - val_loss: 4.2929 - 125ms/epoch - 10ms/step
# Epoch 96/100
# 13/13 - 0s - loss: 4.6211 - val_loss: 4.3645 - 110ms/epoch - 8ms/step
# Epoch 97/100
# 13/13 - 0s - loss: 4.6488 - val_loss: 4.3468 - 132ms/epoch - 10ms/step
# Epoch 98/100
# 13/13 - 0s - loss: 4.6597 - val_loss: 4.3023 - 126ms/epoch - 10ms/step
# Epoch 99/100
# 13/13 - 0s - loss: 4.6514 - val_loss: 4.3172 - 134ms/epoch - 10ms/step
# Epoch 100/100
# 13/13 - 0s - loss: 4.6573 - val_loss: 4.3028 - 141ms/epoch - 11ms/step
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000238C600C040> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# MAE: 4.653 (0.142)
# R2: -0.034 (0.045)
# Pearsonr: 0.195 (0.165)
